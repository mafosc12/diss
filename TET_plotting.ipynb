# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import os
# Out:
# C:\Users\hugma\AppData\Local\Temp\ipykernel_23932\3256943028.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
filelocation_TET = 'NDT_all_12thDec_uncleaned.csv'
header = "Subject"
feelings = ['MetaAwareness','Presence','PhysicalEffort','MentalEffort','Boredom', 'Receptivity', 'EmotionalIntensity', 'Clarity', 'Release', 'Bliss', 'Embodiment', 'Insightfulness', 'Anxiety', 'SpiritualExperience']

# %%
class csv_splitter:

    def __init__(self,excel_file_name):
        self.excel_file_location = f'c:\\Users\\hugma\\diss\\{excel_file_name}'
        self.dataframes = None
    def read_excel(self):
        try:
            df_excel_file_name = pd.read_csv(self.excel_file_location)
            return df_excel_file_name
        except Exception as e:
            print(f"error reading Excel file: {e}")
    def split_by_header(self,df_excel_file_name, heading):
        if heading not in df_excel_file_name.columns:
            print(f"Error: '{heading}' not found in DataFrame columns.")
            return None
        heading_values = df_excel_file_name[heading].unique()
        split_df = {value: df_excel_file_name[df_excel_file_name[heading] == value] for value in heading_values}
        split_df_array = [[key, value] for key, value in split_df.items()]
        return split_df, split_df_array

# %%
csv_splitter_instance = csv_splitter(filelocation_TET)
df_csv_file = csv_splitter_instance.read_excel()
split_df, split_csv_array = csv_splitter_instance.split_by_header(df_csv_file,header)

# %%
split_dict = {}
for (subject, week, session), group in df_csv_file.groupby(['Subject', 'Week', 'Session']):
    split_dict[(subject, week, session)] = group.copy()

# %%
plt.figure()

for feeling in feelings:
    y_values  = split_dict['s01\\', 'week_1', 'run_01'][feeling]
    x_values =
# Out:
# 0     run_01
# 1     run_01
# 2     run_01
# 3     run_01
# 4     run_01
# 5     run_01
# 6     run_01
# 7     run_01
# 8     run_01
# 9     run_01
# 10    run_01
# 11    run_01
# 12    run_01
# 13    run_01
# 14    run_01
# 15    run_01
# 16    run_01
# 17    run_01
# 18    run_01
# 19    run_01
# 20    run_01
# 21    run_01
# 22    run_01
# 23    run_01
# 24    run_01
# 25    run_01
# 26    run_01
# 27    run_01
# 28    run_01
# 29    run_01
# 30    run_01
# 31    run_01
# 32    run_01
# 33    run_01
# 34    run_01
# 35    run_01
# 36    run_01
# 37    run_01
# 38    run_01
# 39    run_01
# 40    run_01
# 41    run_01
# 42    run_01
# Name: Session, dtype: object

# %%
for value in split_dict.values():
    plt.figure()
    for i in range(4,18):
        y_values =
# Out:
#    Subject    Week Session Condition  MetaAwareness  Presence  PhysicalEffort  \
# 0     s01\  week_1  run_01     Intro       0.079752  0.157927        0.986157
# 1     s01\  week_1  run_01     Intro       0.090521  0.154184        0.988758
# 2     s01\  week_1  run_01    Breath       0.103346  0.170191        0.996748
# 3     s01\  week_1  run_01    Breath       0.113467  0.184691        0.996189
# 4     s01\  week_1  run_01    Breath       0.122709  0.201506        0.994991
# 5     s01\  week_1  run_01    Breath       0.131016  0.215564        1.000000
# 6     s01\  week_1  run_01    Breath       0.140421  0.232716        0.995477
# 7     s01\  week_1  run_01    Breath       0.146483  0.246589        0.994702
# 8     s01\  week_1  run_01    Breath       0.159931  0.254412        0.984740
# 9     s01\  week_1  run_01    Breath       0.171834  0.270018        0.978822
# 10    s01\  week_1  run_01    Breath       0.188204  0.281592        0.978163
# 11    s01\  week_1  run_01    Breath       0.203103  0.292852        0.961638
# 12    s01\  week_1  run_01      Hold       0.223225  0.304503        0.940899
# 13    s01\  week_1  run_01      Hold       0.239681  0.315908        0.926445
# 14    s01\  week_1  run_01      Hold       0.258907  0.328468        0.908909
# 15    s01\  week_1  run_01      Hold       0.278132  0.349283        0.900467
# 16    s01\  week_1  run_01      Hold       0.291381  0.371211        0.889959
# 17    s01\  week_1  run_01      Rest       0.317718  0.383641        0.880215
# 18    s01\  week_1  run_01      Rest       0.346278  0.389635        0.879283
# 19    s01\  week_1  run_01      Rest       0.371188  0.397301        0.873622
# 20    s01\  week_1  run_01      Rest       0.396598  0.408096        0.873896
# 21    s01\  week_1  run_01    Breath       0.420263  0.430379        0.873992
# 22    s01\  week_1  run_01    Breath       0.441209  0.453575        0.871843
# 23    s01\  week_1  run_01    Breath       0.454183  0.472461        0.871295
# 24    s01\  week_1  run_01    Breath       0.462073  0.476960        0.865607
# 25    s01\  week_1  run_01    Breath       0.469798  0.475250        0.850395
# 26    s01\  week_1  run_01    Breath       0.477556  0.475373        0.834474
# 27    s01\  week_1  run_01    Breath       0.471326  0.474620        0.821122
# 28    s01\  week_1  run_01    Breath       0.475315  0.472148        0.817596
# 29    s01\  week_1  run_01    Breath       0.489196  0.470864        0.816614
# 30    s01\  week_1  run_01    Breath       0.494162  0.474027        0.807536
# 31    s01\  week_1  run_01      Hold       0.496095  0.480676        0.789347
# 32    s01\  week_1  run_01      Hold       0.502185  0.487292        0.764444
# 33    s01\  week_1  run_01      Hold       0.499285  0.489789        0.743835
# 34    s01\  week_1  run_01      Hold       0.500382  0.489426        0.739007
# 35    s01\  week_1  run_01       END       0.501921  0.498502        0.726491
# 36    s01\  week_1  run_01       END       0.504078  0.525373        0.712926
# 37    s01\  week_1  run_01       END       0.506372  0.539213        0.697477
# 38    s01\  week_1  run_01       END       0.506621  0.553375        0.688459
# 39    s01\  week_1  run_01       END       0.508023  0.571285        0.677539
# 40    s01\  week_1  run_01       END       0.509180  0.582786        0.650588
# 41    s01\  week_1  run_01       END       0.512385  0.580030        0.638820
# 42    s01\  week_1  run_01       END       0.522090  0.577154        0.641016
#
#     MentalEffort   Boredom  Receptivity  ...     delta     theta     alpha  \
# 0       0.864791  0.358931     0.325571  ...       NaN       NaN       NaN
# 1       0.846303  0.335205     0.327787  ...       NaN       NaN       NaN
# 2       0.830982  0.351663     0.325911  ...  0.331450  0.460067       NaN
# 3       0.820543  0.373540     0.325817  ...  0.305562  0.454785  0.318854
# 4       0.805797  0.395632     0.323555  ...       NaN       NaN       NaN
# 5       0.789672  0.413669     0.324230  ...  0.218893  0.383112  0.373777
# 6       0.773816  0.437407     0.326418  ...       NaN       NaN       NaN
# 7       0.762033  0.452063     0.328492  ...       NaN       NaN       NaN
# 8       0.750584  0.487545     0.337645  ...  0.351458  0.576127  0.251023
# 9       0.742503  0.537554     0.347985  ...  0.301731  0.677782  0.251291
# 10      0.742370  0.569972     0.362047  ...  0.329219  0.634705  0.159487
# 11      0.736779  0.563756     0.372891  ...  0.485136  0.557041  0.258140
# 12      0.726441  0.573593     0.386516  ...       NaN       NaN       NaN
# 13      0.708581  0.581331     0.399272  ...       NaN       NaN       NaN
# 14      0.687913  0.593582     0.407142  ...       NaN       NaN       NaN
# 15      0.667826  0.601439     0.407213  ...  0.535047  0.718864  0.166663
# 16      0.647876  0.613660     0.405996  ...  0.382863  0.503464  0.245063
# 17      0.625321  0.629787     0.407161  ...       NaN  0.436555  0.269936
# 18      0.608439  0.651710     0.405851  ...  0.281752  0.355959  0.205857
# 19      0.590375  0.661133     0.398248  ...  0.662904  0.340866  0.339366
# 20      0.575642  0.669370     0.407719  ...  0.368287  0.349387       NaN
# 21      0.558102  0.666732     0.408880  ...       NaN       NaN       NaN
# 22      0.543868  0.664871     0.427644  ...       NaN       NaN       NaN
# 23      0.528541  0.669168     0.434808  ...       NaN       NaN       NaN
# 24      0.513934  0.675704     0.435144  ...       NaN       NaN       NaN
# 25      0.499779  0.696238     0.437159  ...  0.466606  0.288173  0.252383
# 26      0.475734  0.710582     0.431978  ...       NaN       NaN       NaN
# 27      0.451235  0.711482     0.417693  ...  0.543240  0.499464  0.255574
# 28      0.435732  0.706880     0.411510  ...       NaN  0.507976  0.226016
# 29      0.428495  0.697305     0.404246  ...  0.417615  0.784337  0.260345
# 30      0.419379  0.684103     0.401794  ...  0.251475  0.609498  0.175282
# 31      0.417806  0.671888     0.398580  ...  0.324140  0.574971  0.189092
# 32      0.423303  0.660559     0.397518  ...  0.376765  0.494904  0.257994
# 33      0.427041  0.660340     0.397152  ...  0.642924  0.468995       NaN
# 34      0.430726  0.653478     0.400533  ...  0.601551       NaN       NaN
# 35      0.421842  0.656783     0.404984  ...  0.398292  0.327196  0.279017
# 36      0.413776  0.661683     0.404396  ...  0.928250  0.649184  0.206293
# 37      0.420633  0.670737     0.401383  ...  0.217490  0.371540  0.180305
# 38      0.423348  0.682717     0.412909  ...       NaN  0.531946  0.368347
# 39      0.426584  0.690136     0.419437  ...       NaN       NaN       NaN
# 40      0.431275  0.707517     0.425144  ...       NaN       NaN       NaN
# 41      0.437851  0.723094     0.436452  ...       NaN       NaN       NaN
# 42      0.442768  0.721139     0.439839  ...       NaN       NaN       NaN
#
#         beta  gamma    offset  exponent  Cluster  BH_Num  before_or_after
# 0        NaN    NaN       NaN       NaN        2     NaN              NaN
# 1   0.672414    NaN  3.621908  2.347230        2     NaN              NaN
# 2   0.688761    NaN  3.239157  2.322005        2     NaN              NaN
# 3   0.544952    NaN  3.467290  2.343427        2     NaN              NaN
# 4        NaN    NaN       NaN       NaN        2     NaN              NaN
# 5   0.880069    NaN  3.366541  2.293092        2     NaN              NaN
# 6        NaN    NaN       NaN       NaN        2     NaN              NaN
# 7        NaN    NaN       NaN       NaN        2     NaN              NaN
# 8   0.665869    NaN  3.021526  2.138718        2     NaN              NaN
# 9   0.616837    NaN  2.512758  1.858621        2     NaN              NaN
# 10  0.650349    NaN  2.377344  1.781613        2     NaN              NaN
# 11  0.690230    NaN  2.549192  1.988653        2     1.0              1.0
# 12       NaN    NaN       NaN       NaN        2     NaN              NaN
# 13       NaN    NaN       NaN       NaN        2     1.0              2.0
# 14       NaN    NaN       NaN       NaN        2     NaN              NaN
# 15  0.509587    NaN  2.890110  2.141437        2     NaN              NaN
# 16  0.622447    NaN  2.571047  1.973004        2     NaN              NaN
# 17  0.805669    NaN  2.688779  2.086448        2     NaN              NaN
# 18  0.569677    NaN  2.921096  2.143444        2     NaN              NaN
# 19  0.745899    NaN  3.168129  2.386057        2     NaN              NaN
# 20  0.571004    NaN  2.784695  2.137896        2     NaN              NaN
# 21       NaN    NaN       NaN       NaN        2     NaN              NaN
# 22       NaN    NaN       NaN       NaN        2     NaN              NaN
# 23       NaN    NaN       NaN       NaN        2     NaN              NaN
# 24       NaN    NaN       NaN       NaN        2     NaN              NaN
# 25  0.634367    NaN  2.059704  1.862442        2     NaN              NaN
# 26       NaN    NaN       NaN       NaN        2     NaN              NaN
# 27  0.673588    NaN  2.428853  1.924181        2     NaN              NaN
# 28  0.546684    NaN  2.187767  1.668917        2     NaN              NaN
# 29  0.477151    NaN  1.801497  1.438651        2     NaN              NaN
# 30  0.468169    NaN  1.887435  1.515466        2     2.0              1.0
# 31  0.574075    NaN  2.090535  1.545247        2     NaN              NaN
# 32  0.581974    NaN  1.843132  1.419589        2     NaN              NaN
# 33  0.567822    NaN  2.732894  1.895931        2     NaN              NaN
# 34  0.508491    NaN  3.112042  2.149847        2     2.0              2.0
# 35  0.822663    NaN  3.214055  2.174356        2     NaN              NaN
# 36  0.727527    NaN  2.851004  2.206258        1     NaN              NaN
# 37  0.632621    NaN  2.719407  2.090125        1     NaN              NaN
# 38  0.493006    NaN  2.499299  1.817527        1     NaN              NaN
# 39       NaN    NaN       NaN       NaN        1     NaN              NaN
# 40       NaN    NaN       NaN       NaN        1     NaN              NaN
# 41       NaN    NaN       NaN       NaN        1     NaN              NaN
# 42       NaN    NaN       NaN       NaN        1     NaN              NaN
#
# [43 rows x 40 columns]
