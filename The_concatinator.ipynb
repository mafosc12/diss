# %%
import pandas as pd
import numpy as np
import os
# Out:
# C:\Users\hugma\AppData\Local\Temp\ipykernel_24740\2619883542.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def load_processed_results(base_directory):
    """
    Load processed wSMI results from a base directory where CSV files are stored.
    
    Parameters:
    - base_directory (str): Base directory from which to load the CSV files.
    
    Returns:
    - A dictionary containing DataFrames with keys based on the subject, week, and session.
    """
    results = {}
    for subject in os.listdir(base_directory):
        subject_path = os.path.join(base_directory, subject)
        if os.path.isdir(subject_path):
            results[subject] = {}
            for week in os.listdir(subject_path):
                week_path = os.path.join(subject_path, week)
                if os.path.isdir(week_path):
                    results[subject][week] = {}
                    for file in os.listdir(week_path):
                        if file.endswith('tau4.csv'):
                            # Correctly extract the session identifier
                            session_parts = file.split('_')
                            session_index = 2 if session_parts[0] == 'session' else 1  # Adjust based on your file naming if needed
                            session = '_'.join(session_parts[:session_index+1])  # This includes the full 'session_X'
                            file_path = os.path.join(week_path, file)
                            results[subject][week][session] = pd.read_csv(file_path)
                            print(f"Loaded data from {file_path}")
    return results

# Example usage
base_dir = r'C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4'
loaded_results = load_processed_results(base_dir)
# Out:
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_1\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_2\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_2\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_2\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_3\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_3\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_3\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_4\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_4\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_4\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_4\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_4\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_4\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s01\week_4\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_1\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_2\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_2\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_2\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_3\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_3\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_3\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_3\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_4\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_4\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_4\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_4\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_4\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_4\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s02\week_4\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_1\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_2\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_2\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_2\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_3\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_3\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_4\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_4\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_4\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_4\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_4\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s03\week_4\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_1\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_4\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_4\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_4\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_4\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_4\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s04\week_4\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_1\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_2\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_2\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_2\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_3\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_3\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_3\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_3\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s07\week_4\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_2\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_3\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s08\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_2\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_4\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_4\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_4\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s10\week_4\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s13\week_3\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_1\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_1\session_session_8_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_2\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_2\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_2\session_session_8_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_3\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_3\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s14\week_3\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_1\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_2\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_3\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_3\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_3\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_4\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_4\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s17\week_4\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_1\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_2\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_2\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_3\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_3\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_3\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_4\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_4\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_4\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_4\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_4\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s18\week_4\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_1\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_1\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_1\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_1\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_1\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_1\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_2\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_2\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_2\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_2\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_2\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_2\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_2\session_session_7_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_3\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_3\session_session_2_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_3\session_session_3_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_3\session_session_4_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_3\session_session_5_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_3\session_session_6_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_4\session_session_1_wsmi_tau4.csv
# Loaded data from C:/Users/hugma/diss/Breathwork EEG Data/Dreem_Pilot/Processed_Results_bplz_tau4\s21\week_4\session_session_2_wsmi_tau4.csv

# %%
loaded_results['s14']['week_2']['session_session_4']
# Out:
#      Channel1  Channel2  Channel3  Channel4  Channel5  Channel6  Channel7  \
# 0         196       182       167       197       194       181       159
# 1         189       181       151       199       177       177       156
# 2         177       183       157       193       187       179       155
# 3         182       169       158       203       181       174       154
# 4         174       184       155       199       180       169       151
# ..        ...       ...       ...       ...       ...       ...       ...
# 446       107       150        78       158        99       156        69
# 447       112       156        87       165       100       152        86
# 448       203       151       195       166       208       153       197
# 449       210       138       194       168       210       149       190
# 450       104       156        86       159       107       153        82
#
#      Channel8  timestamps
# 0         182       156.0
# 1         178       157.0
# 2         175       160.0
# 3         184       165.0
# 4         180       166.0
# ..        ...         ...
# 446       157       677.0
# 447       157       678.0
# 448       157       680.0
# 449       152       681.0
# 450       159       682.0
#
# [451 rows x 9 columns]

# %%
def process_wsmi_data(data, subject, week, session):
    """
    Process wSMI data directly from a DataFrame, calculate intervals, attach session identifiers, and average values by interval.

    Parameters:
    - data (DataFrame): The DataFrame containing the wSMI data.
    - subject (str): The subject identifier.
    - week (str): The week identifier.
    - session (str): The session identifier.

    Returns:
    - DataFrame: Aggregated DataFrame with mean wSMI values by interval.
    """
    # Debug: Print the current shape and column names of the data
    print("Current DataFrame shape:", data.shape)
    print("Current DataFrame columns:", data.columns.tolist())

    # Ensure the DataFrame has exactly four expected columns before renaming
    if len(data.columns) == 9:
        data.columns = ['channel_1_bplz_4', 'channel_2_bplz_4','channel_3_bplz_4','channel_4_bplz_4','channel_5_bplz_4','channel_6_bplz_4','channel_7_bplz_4','channel_8_bplz_4', 'timestamp']
    else:
        raise ValueError("Data does not have the expected number of columns (4)")

    data['timestamp'] = data['timestamp'].astype(float) * 4  # Convert epochs to seconds
    data['interval'] = (data['timestamp'] // 28).astype(int)  # Compute the interval index
    data['Subject'] = subject
    data['Week'] = week
    data['Session'] = session

    # Aggregate data by 'Subject', 'Week', 'Session', and 'interval'
    aggregated = data.groupby(['Subject', 'Week', 'Session', 'interval']).agg({
        'channel_1_bplz_4': 'mean',
        'channel_2_bplz_4': 'mean',
        'channel_3_bplz_4': 'mean',
        'channel_4_bplz_4': 'mean',
        'channel_5_bplz_4': 'mean',
        'channel_6_bplz_4': 'mean',
        'channel_7_bplz_4': 'mean',
        'channel_8_bplz_4': 'mean',

    }).reset_index()
    return aggregated
def add_wsmi_data_to_main(main_df, wsmi_data):
    """ Add wSMI data to the main DataFrame under the specified columns. """
    for index, row in wsmi_data.iterrows():
        condition = (
            (main_df['Subject'] == row['Subject']) &
            (main_df['Week'] == row['Week']) &
            (main_df['Session'] == row['Session']) &
            (main_df['interval'] == row['interval'])
        )
        if condition.any():
            main_df.loc[condition, 'channel_1_bplz_4'] = row['channel_1_bplz_4']
            main_df.loc[condition, 'channel_2_bplz_4'] = row['channel_2_bplz_4']
            main_df.loc[condition, 'channel_3_bplz_4'] = row['channel_3_bplz_4']
            main_df.loc[condition, 'channel_4_bplz_4'] = row['channel_4_bplz_4']
            main_df.loc[condition, 'channel_5_bplz_4'] = row['channel_5_bplz_4']
            main_df.loc[condition, 'channel_6_bplz_4'] = row['channel_6_bplz_4']
            main_df.loc[condition, 'channel_7_bplz_4'] = row['channel_7_bplz_4']
            main_df.loc[condition, 'channel_8_bplz_4'] = row['channel_8_bplz_4']
        else:
            print(f"No match found for {row['Subject']}, {row['Week']}, {row['Session']}, Interval {row['interval']}")
    return main_df
session_mapping = {
    'session_session_1': 'run_01',
    'session_session_2': 'run_02',
    'session_session_3': 'run_03',
    'session_session_4': 'run_04',
    'session_session_5': 'run_05',
    'session_session_6': 'run_06',
    'session_session_7': 'run_07',
    }

main_df_path = "C:/Users/hugma/diss/final/main_df.csv"
main_df = pd.read_csv(main_df_path)
def process_wsmi_data(data, subject, week, session):
    """
    Process wSMI data directly from a DataFrame, calculate intervals, attach session identifiers, and average values by interval.
    """
    # Apply correct column names
    data.columns = ['channel_1_bplz_4', 'channel_2_bplz_4','channel_3_bplz_4','channel_4_bplz_4','channel_5_bplz_4','channel_6_bplz_4','channel_7_bplz_4','channel_8_bplz_4', 'timestamp']
    
    # Convert timestamp to seconds and calculate interval
    data['timestamp'] = data['timestamp'].astype(float) * 4  # Assuming 'timestamp' is the last column
    data['interval'] = (data['timestamp'] // 28).astype(int)
    
    # Assign additional identifiers
    data['Subject'] = subject
    data['Week'] = week
    data['Session'] = session

    # Aggregate data by 'Subject', 'Week', 'Session', and 'interval'
    aggregated = data.groupby(['Subject', 'Week', 'Session', 'interval']).agg({
        'channel_1_bplz_4': 'mean',
        'channel_2_bplz_4': 'mean',
        'channel_3_bplz_4': 'mean',
        'channel_4_bplz_4': 'mean',
        'channel_5_bplz_4': 'mean',
        'channel_6_bplz_4': 'mean',
        'channel_7_bplz_4': 'mean',
        'channel_8_bplz_4': 'mean',
    }).reset_index()
    return aggregated

for subject, weeks in loaded_results.items():
    for week, sessions in weeks.items():
        for session, data in sessions.items():
            # Apply the session mapping
            standardized_session = session_mapping.get(session, session)  # Default to original if not found in map
            
            # Print mapping information for debugging
            print(f"Mapping {session} to {standardized_session}")

            # Process the data using the modified function
            processed_data = process_wsmi_data(data, subject, week, standardized_session)

            # Now call the function to add this processed data to the main DataFrame
            main_df = add_wsmi_data_to_main(main_df, processed_data)
# Out:
# Mapping session_session_1 to run_01
# No match found for s01, week_1, run_01, Interval 43
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# No match found for s01, week_1, run_04, Interval 43
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# No match found for s01, week_2, run_01, Interval 0
# No match found for s01, week_2, run_01, Interval 1
# No match found for s01, week_2, run_01, Interval 2
# No match found for s01, week_2, run_01, Interval 3
# No match found for s01, week_2, run_01, Interval 4
# No match found for s01, week_2, run_01, Interval 5
# No match found for s01, week_2, run_01, Interval 6
# No match found for s01, week_2, run_01, Interval 7
# No match found for s01, week_2, run_01, Interval 8
# No match found for s01, week_2, run_01, Interval 9
# No match found for s01, week_2, run_01, Interval 10
# No match found for s01, week_2, run_01, Interval 11
# No match found for s01, week_2, run_01, Interval 12
# No match found for s01, week_2, run_01, Interval 13
# No match found for s01, week_2, run_01, Interval 14
# No match found for s01, week_2, run_01, Interval 15
# No match found for s01, week_2, run_01, Interval 16
# No match found for s01, week_2, run_01, Interval 17
# No match found for s01, week_2, run_01, Interval 18
# No match found for s01, week_2, run_01, Interval 19
# No match found for s01, week_2, run_01, Interval 20
# No match found for s01, week_2, run_01, Interval 22
# No match found for s01, week_2, run_01, Interval 23
# No match found for s01, week_2, run_01, Interval 24
# No match found for s01, week_2, run_01, Interval 25
# No match found for s01, week_2, run_01, Interval 26
# No match found for s01, week_2, run_01, Interval 27
# No match found for s01, week_2, run_01, Interval 28
# No match found for s01, week_2, run_01, Interval 29
# No match found for s01, week_2, run_01, Interval 30
# No match found for s01, week_2, run_01, Interval 31
# No match found for s01, week_2, run_01, Interval 32
# No match found for s01, week_2, run_01, Interval 33
# No match found for s01, week_2, run_01, Interval 34
# No match found for s01, week_2, run_01, Interval 35
# No match found for s01, week_2, run_01, Interval 36
# No match found for s01, week_2, run_01, Interval 37
# No match found for s01, week_2, run_01, Interval 38
# No match found for s01, week_2, run_01, Interval 39
# No match found for s01, week_2, run_01, Interval 40
# No match found for s01, week_2, run_01, Interval 41
# No match found for s01, week_2, run_01, Interval 42
# No match found for s01, week_2, run_01, Interval 43
# No match found for s01, week_2, run_01, Interval 44
# No match found for s01, week_2, run_01, Interval 45
# No match found for s01, week_2, run_01, Interval 46
# No match found for s01, week_2, run_01, Interval 47
# No match found for s01, week_2, run_01, Interval 48
# No match found for s01, week_2, run_01, Interval 49
# No match found for s01, week_2, run_01, Interval 50
# No match found for s01, week_2, run_01, Interval 51
# No match found for s01, week_2, run_01, Interval 52
# No match found for s01, week_2, run_01, Interval 53
# No match found for s01, week_2, run_01, Interval 54
# No match found for s01, week_2, run_01, Interval 55
# No match found for s01, week_2, run_01, Interval 56
# No match found for s01, week_2, run_01, Interval 57
# No match found for s01, week_2, run_01, Interval 58
# No match found for s01, week_2, run_01, Interval 59
# No match found for s01, week_2, run_01, Interval 60
# No match found for s01, week_2, run_01, Interval 61
# No match found for s01, week_2, run_01, Interval 62
# No match found for s01, week_2, run_01, Interval 63
# No match found for s01, week_2, run_01, Interval 64
# No match found for s01, week_2, run_01, Interval 66
# No match found for s01, week_2, run_01, Interval 67
# No match found for s01, week_2, run_01, Interval 68
# No match found for s01, week_2, run_01, Interval 69
# No match found for s01, week_2, run_01, Interval 70
# No match found for s01, week_2, run_01, Interval 71
# No match found for s01, week_2, run_01, Interval 72
# No match found for s01, week_2, run_01, Interval 73
# No match found for s01, week_2, run_01, Interval 74
# No match found for s01, week_2, run_01, Interval 75
# No match found for s01, week_2, run_01, Interval 76
# No match found for s01, week_2, run_01, Interval 77
# No match found for s01, week_2, run_01, Interval 78
# No match found for s01, week_2, run_01, Interval 79
# No match found for s01, week_2, run_01, Interval 80
# No match found for s01, week_2, run_01, Interval 81
# No match found for s01, week_2, run_01, Interval 82
# No match found for s01, week_2, run_01, Interval 83
# No match found for s01, week_2, run_01, Interval 84
# No match found for s01, week_2, run_01, Interval 85
# No match found for s01, week_2, run_01, Interval 86
# No match found for s01, week_2, run_01, Interval 87
# No match found for s01, week_2, run_01, Interval 88
# No match found for s01, week_2, run_01, Interval 89
# No match found for s01, week_2, run_01, Interval 90
# No match found for s01, week_2, run_01, Interval 91
# No match found for s01, week_2, run_01, Interval 92
# No match found for s01, week_2, run_01, Interval 93
# No match found for s01, week_2, run_01, Interval 94
# No match found for s01, week_2, run_01, Interval 95
# No match found for s01, week_2, run_01, Interval 96
# No match found for s01, week_2, run_01, Interval 97
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# No match found for s01, week_2, run_03, Interval 97
# Mapping session_session_4 to run_04
# No match found for s01, week_2, run_04, Interval 97
# Mapping session_session_5 to run_05
# No match found for s01, week_2, run_05, Interval 97
# Mapping session_session_6 to run_06
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# No match found for s01, week_4, run_06, Interval 45
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# No match found for s02, week_1, run_01, Interval 43
# Mapping session_session_2 to run_02
# No match found for s02, week_1, run_02, Interval 43
# Mapping session_session_3 to run_03
# No match found for s02, week_1, run_03, Interval 43
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# No match found for s02, week_1, run_05, Interval 43
# Mapping session_session_6 to run_06
# No match found for s02, week_1, run_06, Interval 43
# Mapping session_session_7 to run_07
# No match found for s02, week_1, run_07, Interval 43
# Mapping session_session_1 to run_01
# No match found for s02, week_2, run_01, Interval 0
# No match found for s02, week_2, run_01, Interval 1
# No match found for s02, week_2, run_01, Interval 2
# No match found for s02, week_2, run_01, Interval 3
# No match found for s02, week_2, run_01, Interval 4
# No match found for s02, week_2, run_01, Interval 5
# No match found for s02, week_2, run_01, Interval 6
# No match found for s02, week_2, run_01, Interval 7
# No match found for s02, week_2, run_01, Interval 8
# No match found for s02, week_2, run_01, Interval 9
# No match found for s02, week_2, run_01, Interval 10
# No match found for s02, week_2, run_01, Interval 11
# No match found for s02, week_2, run_01, Interval 12
# No match found for s02, week_2, run_01, Interval 13
# No match found for s02, week_2, run_01, Interval 14
# No match found for s02, week_2, run_01, Interval 15
# No match found for s02, week_2, run_01, Interval 16
# No match found for s02, week_2, run_01, Interval 17
# No match found for s02, week_2, run_01, Interval 18
# No match found for s02, week_2, run_01, Interval 19
# No match found for s02, week_2, run_01, Interval 20
# No match found for s02, week_2, run_01, Interval 21
# No match found for s02, week_2, run_01, Interval 22
# No match found for s02, week_2, run_01, Interval 23
# No match found for s02, week_2, run_01, Interval 24
# No match found for s02, week_2, run_01, Interval 25
# No match found for s02, week_2, run_01, Interval 26
# No match found for s02, week_2, run_01, Interval 27
# No match found for s02, week_2, run_01, Interval 28
# No match found for s02, week_2, run_01, Interval 29
# No match found for s02, week_2, run_01, Interval 30
# No match found for s02, week_2, run_01, Interval 31
# No match found for s02, week_2, run_01, Interval 32
# No match found for s02, week_2, run_01, Interval 33
# No match found for s02, week_2, run_01, Interval 34
# No match found for s02, week_2, run_01, Interval 35
# No match found for s02, week_2, run_01, Interval 36
# No match found for s02, week_2, run_01, Interval 37
# No match found for s02, week_2, run_01, Interval 38
# No match found for s02, week_2, run_01, Interval 39
# No match found for s02, week_2, run_01, Interval 40
# No match found for s02, week_2, run_01, Interval 41
# No match found for s02, week_2, run_01, Interval 42
# No match found for s02, week_2, run_01, Interval 43
# No match found for s02, week_2, run_01, Interval 44
# No match found for s02, week_2, run_01, Interval 45
# No match found for s02, week_2, run_01, Interval 46
# No match found for s02, week_2, run_01, Interval 47
# No match found for s02, week_2, run_01, Interval 48
# No match found for s02, week_2, run_01, Interval 49
# No match found for s02, week_2, run_01, Interval 50
# No match found for s02, week_2, run_01, Interval 51
# No match found for s02, week_2, run_01, Interval 52
# No match found for s02, week_2, run_01, Interval 53
# No match found for s02, week_2, run_01, Interval 54
# No match found for s02, week_2, run_01, Interval 55
# No match found for s02, week_2, run_01, Interval 56
# No match found for s02, week_2, run_01, Interval 57
# No match found for s02, week_2, run_01, Interval 58
# No match found for s02, week_2, run_01, Interval 59
# No match found for s02, week_2, run_01, Interval 60
# No match found for s02, week_2, run_01, Interval 61
# No match found for s02, week_2, run_01, Interval 62
# No match found for s02, week_2, run_01, Interval 63
# No match found for s02, week_2, run_01, Interval 64
# No match found for s02, week_2, run_01, Interval 65
# No match found for s02, week_2, run_01, Interval 66
# No match found for s02, week_2, run_01, Interval 67
# No match found for s02, week_2, run_01, Interval 68
# No match found for s02, week_2, run_01, Interval 69
# No match found for s02, week_2, run_01, Interval 70
# No match found for s02, week_2, run_01, Interval 71
# No match found for s02, week_2, run_01, Interval 72
# No match found for s02, week_2, run_01, Interval 73
# No match found for s02, week_2, run_01, Interval 74
# No match found for s02, week_2, run_01, Interval 75
# No match found for s02, week_2, run_01, Interval 76
# No match found for s02, week_2, run_01, Interval 77
# No match found for s02, week_2, run_01, Interval 78
# No match found for s02, week_2, run_01, Interval 79
# No match found for s02, week_2, run_01, Interval 80
# No match found for s02, week_2, run_01, Interval 81
# No match found for s02, week_2, run_01, Interval 82
# No match found for s02, week_2, run_01, Interval 83
# No match found for s02, week_2, run_01, Interval 84
# No match found for s02, week_2, run_01, Interval 85
# No match found for s02, week_2, run_01, Interval 86
# No match found for s02, week_2, run_01, Interval 87
# No match found for s02, week_2, run_01, Interval 88
# No match found for s02, week_2, run_01, Interval 89
# No match found for s02, week_2, run_01, Interval 90
# No match found for s02, week_2, run_01, Interval 91
# No match found for s02, week_2, run_01, Interval 92
# No match found for s02, week_2, run_01, Interval 93
# No match found for s02, week_2, run_01, Interval 94
# No match found for s02, week_2, run_01, Interval 95
# No match found for s02, week_2, run_01, Interval 96
# No match found for s02, week_2, run_01, Interval 97
# Mapping session_session_2 to run_02
# No match found for s02, week_2, run_02, Interval 97
# Mapping session_session_3 to run_03
# No match found for s02, week_2, run_03, Interval 97
# Mapping session_session_4 to run_04
# No match found for s02, week_2, run_04, Interval 0
# No match found for s02, week_2, run_04, Interval 1
# No match found for s02, week_2, run_04, Interval 2
# No match found for s02, week_2, run_04, Interval 3
# No match found for s02, week_2, run_04, Interval 4
# No match found for s02, week_2, run_04, Interval 5
# No match found for s02, week_2, run_04, Interval 6
# No match found for s02, week_2, run_04, Interval 7
# No match found for s02, week_2, run_04, Interval 8
# No match found for s02, week_2, run_04, Interval 9
# No match found for s02, week_2, run_04, Interval 10
# No match found for s02, week_2, run_04, Interval 11
# No match found for s02, week_2, run_04, Interval 12
# No match found for s02, week_2, run_04, Interval 13
# No match found for s02, week_2, run_04, Interval 14
# No match found for s02, week_2, run_04, Interval 15
# No match found for s02, week_2, run_04, Interval 16
# No match found for s02, week_2, run_04, Interval 17
# No match found for s02, week_2, run_04, Interval 18
# No match found for s02, week_2, run_04, Interval 19
# No match found for s02, week_2, run_04, Interval 20
# No match found for s02, week_2, run_04, Interval 21
# No match found for s02, week_2, run_04, Interval 22
# No match found for s02, week_2, run_04, Interval 23
# No match found for s02, week_2, run_04, Interval 24
# No match found for s02, week_2, run_04, Interval 25
# No match found for s02, week_2, run_04, Interval 26
# No match found for s02, week_2, run_04, Interval 27
# No match found for s02, week_2, run_04, Interval 28
# No match found for s02, week_2, run_04, Interval 29
# No match found for s02, week_2, run_04, Interval 30
# No match found for s02, week_2, run_04, Interval 31
# No match found for s02, week_2, run_04, Interval 32
# No match found for s02, week_2, run_04, Interval 33
# No match found for s02, week_2, run_04, Interval 34
# No match found for s02, week_2, run_04, Interval 35
# No match found for s02, week_2, run_04, Interval 36
# No match found for s02, week_2, run_04, Interval 37
# No match found for s02, week_2, run_04, Interval 38
# No match found for s02, week_2, run_04, Interval 39
# No match found for s02, week_2, run_04, Interval 40
# No match found for s02, week_2, run_04, Interval 41
# No match found for s02, week_2, run_04, Interval 42
# No match found for s02, week_2, run_04, Interval 43
# No match found for s02, week_2, run_04, Interval 44
# No match found for s02, week_2, run_04, Interval 45
# No match found for s02, week_2, run_04, Interval 46
# No match found for s02, week_2, run_04, Interval 47
# No match found for s02, week_2, run_04, Interval 48
# No match found for s02, week_2, run_04, Interval 49
# No match found for s02, week_2, run_04, Interval 50
# No match found for s02, week_2, run_04, Interval 51
# No match found for s02, week_2, run_04, Interval 52
# No match found for s02, week_2, run_04, Interval 53
# No match found for s02, week_2, run_04, Interval 54
# No match found for s02, week_2, run_04, Interval 55
# No match found for s02, week_2, run_04, Interval 56
# No match found for s02, week_2, run_04, Interval 57
# No match found for s02, week_2, run_04, Interval 58
# No match found for s02, week_2, run_04, Interval 59
# No match found for s02, week_2, run_04, Interval 60
# No match found for s02, week_2, run_04, Interval 61
# No match found for s02, week_2, run_04, Interval 62
# No match found for s02, week_2, run_04, Interval 63
# No match found for s02, week_2, run_04, Interval 64
# No match found for s02, week_2, run_04, Interval 65
# No match found for s02, week_2, run_04, Interval 66
# No match found for s02, week_2, run_04, Interval 67
# No match found for s02, week_2, run_04, Interval 68
# No match found for s02, week_2, run_04, Interval 69
# No match found for s02, week_2, run_04, Interval 70
# No match found for s02, week_2, run_04, Interval 71
# No match found for s02, week_2, run_04, Interval 72
# No match found for s02, week_2, run_04, Interval 73
# No match found for s02, week_2, run_04, Interval 74
# No match found for s02, week_2, run_04, Interval 75
# No match found for s02, week_2, run_04, Interval 76
# No match found for s02, week_2, run_04, Interval 77
# No match found for s02, week_2, run_04, Interval 78
# No match found for s02, week_2, run_04, Interval 79
# No match found for s02, week_2, run_04, Interval 80
# No match found for s02, week_2, run_04, Interval 81
# No match found for s02, week_2, run_04, Interval 82
# No match found for s02, week_2, run_04, Interval 83
# No match found for s02, week_2, run_04, Interval 84
# No match found for s02, week_2, run_04, Interval 85
# No match found for s02, week_2, run_04, Interval 86
# No match found for s02, week_2, run_04, Interval 87
# No match found for s02, week_2, run_04, Interval 88
# No match found for s02, week_2, run_04, Interval 89
# No match found for s02, week_2, run_04, Interval 90
# No match found for s02, week_2, run_04, Interval 91
# No match found for s02, week_2, run_04, Interval 92
# No match found for s02, week_2, run_04, Interval 93
# No match found for s02, week_2, run_04, Interval 94
# No match found for s02, week_2, run_04, Interval 95
# No match found for s02, week_2, run_04, Interval 96
# No match found for s02, week_2, run_04, Interval 97
# Mapping session_session_5 to run_05
# No match found for s02, week_2, run_05, Interval 97
# Mapping session_session_6 to run_06
# No match found for s02, week_2, run_06, Interval 0
# No match found for s02, week_2, run_06, Interval 1
# No match found for s02, week_2, run_06, Interval 2
# No match found for s02, week_2, run_06, Interval 3
# No match found for s02, week_2, run_06, Interval 4
# No match found for s02, week_2, run_06, Interval 5
# No match found for s02, week_2, run_06, Interval 6
# No match found for s02, week_2, run_06, Interval 7
# No match found for s02, week_2, run_06, Interval 8
# No match found for s02, week_2, run_06, Interval 9
# No match found for s02, week_2, run_06, Interval 10
# No match found for s02, week_2, run_06, Interval 11
# No match found for s02, week_2, run_06, Interval 12
# No match found for s02, week_2, run_06, Interval 13
# No match found for s02, week_2, run_06, Interval 14
# No match found for s02, week_2, run_06, Interval 15
# No match found for s02, week_2, run_06, Interval 16
# No match found for s02, week_2, run_06, Interval 17
# No match found for s02, week_2, run_06, Interval 18
# No match found for s02, week_2, run_06, Interval 19
# No match found for s02, week_2, run_06, Interval 20
# No match found for s02, week_2, run_06, Interval 21
# No match found for s02, week_2, run_06, Interval 22
# No match found for s02, week_2, run_06, Interval 23
# No match found for s02, week_2, run_06, Interval 24
# No match found for s02, week_2, run_06, Interval 25
# No match found for s02, week_2, run_06, Interval 26
# No match found for s02, week_2, run_06, Interval 27
# No match found for s02, week_2, run_06, Interval 28
# No match found for s02, week_2, run_06, Interval 29
# No match found for s02, week_2, run_06, Interval 30
# No match found for s02, week_2, run_06, Interval 31
# No match found for s02, week_2, run_06, Interval 32
# No match found for s02, week_2, run_06, Interval 33
# No match found for s02, week_2, run_06, Interval 34
# No match found for s02, week_2, run_06, Interval 35
# No match found for s02, week_2, run_06, Interval 36
# No match found for s02, week_2, run_06, Interval 37
# No match found for s02, week_2, run_06, Interval 38
# No match found for s02, week_2, run_06, Interval 39
# No match found for s02, week_2, run_06, Interval 40
# No match found for s02, week_2, run_06, Interval 41
# No match found for s02, week_2, run_06, Interval 42
# No match found for s02, week_2, run_06, Interval 43
# No match found for s02, week_2, run_06, Interval 44
# No match found for s02, week_2, run_06, Interval 45
# No match found for s02, week_2, run_06, Interval 46
# No match found for s02, week_2, run_06, Interval 47
# No match found for s02, week_2, run_06, Interval 48
# No match found for s02, week_2, run_06, Interval 49
# No match found for s02, week_2, run_06, Interval 50
# No match found for s02, week_2, run_06, Interval 51
# No match found for s02, week_2, run_06, Interval 52
# No match found for s02, week_2, run_06, Interval 53
# No match found for s02, week_2, run_06, Interval 54
# No match found for s02, week_2, run_06, Interval 55
# No match found for s02, week_2, run_06, Interval 56
# No match found for s02, week_2, run_06, Interval 57
# No match found for s02, week_2, run_06, Interval 58
# No match found for s02, week_2, run_06, Interval 59
# No match found for s02, week_2, run_06, Interval 60
# No match found for s02, week_2, run_06, Interval 61
# No match found for s02, week_2, run_06, Interval 62
# No match found for s02, week_2, run_06, Interval 63
# No match found for s02, week_2, run_06, Interval 64
# No match found for s02, week_2, run_06, Interval 65
# No match found for s02, week_2, run_06, Interval 66
# No match found for s02, week_2, run_06, Interval 67
# No match found for s02, week_2, run_06, Interval 68
# No match found for s02, week_2, run_06, Interval 69
# No match found for s02, week_2, run_06, Interval 70
# No match found for s02, week_2, run_06, Interval 71
# No match found for s02, week_2, run_06, Interval 72
# No match found for s02, week_2, run_06, Interval 73
# No match found for s02, week_2, run_06, Interval 74
# No match found for s02, week_2, run_06, Interval 75
# No match found for s02, week_2, run_06, Interval 76
# No match found for s02, week_2, run_06, Interval 77
# No match found for s02, week_2, run_06, Interval 78
# No match found for s02, week_2, run_06, Interval 79
# No match found for s02, week_2, run_06, Interval 80
# No match found for s02, week_2, run_06, Interval 81
# No match found for s02, week_2, run_06, Interval 82
# No match found for s02, week_2, run_06, Interval 83
# No match found for s02, week_2, run_06, Interval 84
# No match found for s02, week_2, run_06, Interval 85
# No match found for s02, week_2, run_06, Interval 86
# No match found for s02, week_2, run_06, Interval 87
# No match found for s02, week_2, run_06, Interval 88
# No match found for s02, week_2, run_06, Interval 89
# No match found for s02, week_2, run_06, Interval 90
# No match found for s02, week_2, run_06, Interval 91
# No match found for s02, week_2, run_06, Interval 92
# No match found for s02, week_2, run_06, Interval 93
# No match found for s02, week_2, run_06, Interval 94
# No match found for s02, week_2, run_06, Interval 95
# No match found for s02, week_2, run_06, Interval 96
# No match found for s02, week_2, run_06, Interval 97
# Mapping session_session_7 to run_07
# No match found for s02, week_2, run_07, Interval 0
# No match found for s02, week_2, run_07, Interval 1
# No match found for s02, week_2, run_07, Interval 2
# No match found for s02, week_2, run_07, Interval 3
# No match found for s02, week_2, run_07, Interval 4
# No match found for s02, week_2, run_07, Interval 5
# No match found for s02, week_2, run_07, Interval 6
# No match found for s02, week_2, run_07, Interval 7
# No match found for s02, week_2, run_07, Interval 8
# No match found for s02, week_2, run_07, Interval 9
# No match found for s02, week_2, run_07, Interval 10
# No match found for s02, week_2, run_07, Interval 12
# No match found for s02, week_2, run_07, Interval 13
# No match found for s02, week_2, run_07, Interval 14
# No match found for s02, week_2, run_07, Interval 15
# No match found for s02, week_2, run_07, Interval 16
# No match found for s02, week_2, run_07, Interval 17
# No match found for s02, week_2, run_07, Interval 18
# No match found for s02, week_2, run_07, Interval 19
# No match found for s02, week_2, run_07, Interval 20
# No match found for s02, week_2, run_07, Interval 21
# No match found for s02, week_2, run_07, Interval 22
# No match found for s02, week_2, run_07, Interval 23
# No match found for s02, week_2, run_07, Interval 24
# No match found for s02, week_2, run_07, Interval 25
# No match found for s02, week_2, run_07, Interval 26
# No match found for s02, week_2, run_07, Interval 27
# No match found for s02, week_2, run_07, Interval 28
# No match found for s02, week_2, run_07, Interval 29
# No match found for s02, week_2, run_07, Interval 30
# No match found for s02, week_2, run_07, Interval 31
# No match found for s02, week_2, run_07, Interval 32
# No match found for s02, week_2, run_07, Interval 33
# No match found for s02, week_2, run_07, Interval 34
# No match found for s02, week_2, run_07, Interval 35
# No match found for s02, week_2, run_07, Interval 36
# No match found for s02, week_2, run_07, Interval 37
# No match found for s02, week_2, run_07, Interval 38
# No match found for s02, week_2, run_07, Interval 39
# No match found for s02, week_2, run_07, Interval 40
# No match found for s02, week_2, run_07, Interval 41
# No match found for s02, week_2, run_07, Interval 42
# No match found for s02, week_2, run_07, Interval 43
# No match found for s02, week_2, run_07, Interval 44
# No match found for s02, week_2, run_07, Interval 45
# No match found for s02, week_2, run_07, Interval 46
# No match found for s02, week_2, run_07, Interval 47
# No match found for s02, week_2, run_07, Interval 48
# No match found for s02, week_2, run_07, Interval 49
# No match found for s02, week_2, run_07, Interval 50
# No match found for s02, week_2, run_07, Interval 51
# No match found for s02, week_2, run_07, Interval 52
# No match found for s02, week_2, run_07, Interval 53
# No match found for s02, week_2, run_07, Interval 54
# No match found for s02, week_2, run_07, Interval 55
# No match found for s02, week_2, run_07, Interval 56
# No match found for s02, week_2, run_07, Interval 57
# No match found for s02, week_2, run_07, Interval 58
# No match found for s02, week_2, run_07, Interval 59
# No match found for s02, week_2, run_07, Interval 60
# No match found for s02, week_2, run_07, Interval 61
# No match found for s02, week_2, run_07, Interval 62
# No match found for s02, week_2, run_07, Interval 63
# No match found for s02, week_2, run_07, Interval 64
# No match found for s02, week_2, run_07, Interval 65
# No match found for s02, week_2, run_07, Interval 66
# No match found for s02, week_2, run_07, Interval 67
# No match found for s02, week_2, run_07, Interval 68
# No match found for s02, week_2, run_07, Interval 69
# No match found for s02, week_2, run_07, Interval 70
# No match found for s02, week_2, run_07, Interval 71
# No match found for s02, week_2, run_07, Interval 72
# No match found for s02, week_2, run_07, Interval 73
# No match found for s02, week_2, run_07, Interval 74
# No match found for s02, week_2, run_07, Interval 75
# No match found for s02, week_2, run_07, Interval 76
# No match found for s02, week_2, run_07, Interval 77
# No match found for s02, week_2, run_07, Interval 78
# No match found for s02, week_2, run_07, Interval 79
# No match found for s02, week_2, run_07, Interval 80
# No match found for s02, week_2, run_07, Interval 81
# No match found for s02, week_2, run_07, Interval 82
# No match found for s02, week_2, run_07, Interval 83
# No match found for s02, week_2, run_07, Interval 84
# No match found for s02, week_2, run_07, Interval 85
# No match found for s02, week_2, run_07, Interval 86
# No match found for s02, week_2, run_07, Interval 87
# No match found for s02, week_2, run_07, Interval 88
# No match found for s02, week_2, run_07, Interval 89
# No match found for s02, week_2, run_07, Interval 90
# No match found for s02, week_2, run_07, Interval 91
# No match found for s02, week_2, run_07, Interval 92
# No match found for s02, week_2, run_07, Interval 93
# No match found for s02, week_2, run_07, Interval 94
# No match found for s02, week_2, run_07, Interval 95
# No match found for s02, week_2, run_07, Interval 96
# No match found for s02, week_2, run_07, Interval 97
# Mapping session_session_1 to run_01
# No match found for s02, week_3, run_01, Interval 136
# Mapping session_session_2 to run_02
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# No match found for s02, week_3, run_06, Interval 136
# Mapping session_session_7 to run_07
# No match found for s02, week_3, run_07, Interval 136
# Mapping session_session_1 to run_01
# No match found for s02, week_4, run_01, Interval 45
# Mapping session_session_2 to run_02
# No match found for s02, week_4, run_02, Interval 45
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# No match found for s02, week_4, run_04, Interval 45
# Mapping session_session_5 to run_05
# No match found for s02, week_4, run_05, Interval 45
# Mapping session_session_6 to run_06
# No match found for s02, week_4, run_06, Interval 45
# Mapping session_session_7 to run_07
# No match found for s02, week_4, run_07, Interval 45
# Mapping session_session_1 to run_01
# No match found for s03, week_1, run_01, Interval 43
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# No match found for s03, week_2, run_01, Interval 97
# Mapping session_session_2 to run_02
# No match found for s03, week_2, run_02, Interval 97
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# No match found for s03, week_2, run_06, Interval 97
# Mapping session_session_7 to run_07
# No match found for s03, week_2, run_07, Interval 97
# Mapping session_session_1 to run_01
# No match found for s03, week_3, run_01, Interval 2
# No match found for s03, week_3, run_01, Interval 7
# No match found for s03, week_3, run_01, Interval 13
# No match found for s03, week_3, run_01, Interval 16
# No match found for s03, week_3, run_01, Interval 18
# No match found for s03, week_3, run_01, Interval 19
# No match found for s03, week_3, run_01, Interval 20
# No match found for s03, week_3, run_01, Interval 23
# No match found for s03, week_3, run_01, Interval 24
# No match found for s03, week_3, run_01, Interval 25
# No match found for s03, week_3, run_01, Interval 26
# No match found for s03, week_3, run_01, Interval 27
# No match found for s03, week_3, run_01, Interval 28
# No match found for s03, week_3, run_01, Interval 29
# No match found for s03, week_3, run_01, Interval 30
# No match found for s03, week_3, run_01, Interval 31
# No match found for s03, week_3, run_01, Interval 32
# No match found for s03, week_3, run_01, Interval 33
# No match found for s03, week_3, run_01, Interval 34
# No match found for s03, week_3, run_01, Interval 35
# No match found for s03, week_3, run_01, Interval 36
# No match found for s03, week_3, run_01, Interval 37
# No match found for s03, week_3, run_01, Interval 38
# No match found for s03, week_3, run_01, Interval 39
# No match found for s03, week_3, run_01, Interval 40
# No match found for s03, week_3, run_01, Interval 41
# No match found for s03, week_3, run_01, Interval 42
# No match found for s03, week_3, run_01, Interval 43
# No match found for s03, week_3, run_01, Interval 44
# No match found for s03, week_3, run_01, Interval 45
# No match found for s03, week_3, run_01, Interval 46
# No match found for s03, week_3, run_01, Interval 47
# No match found for s03, week_3, run_01, Interval 48
# No match found for s03, week_3, run_01, Interval 49
# No match found for s03, week_3, run_01, Interval 50
# No match found for s03, week_3, run_01, Interval 51
# No match found for s03, week_3, run_01, Interval 52
# No match found for s03, week_3, run_01, Interval 53
# No match found for s03, week_3, run_01, Interval 54
# No match found for s03, week_3, run_01, Interval 55
# No match found for s03, week_3, run_01, Interval 56
# No match found for s03, week_3, run_01, Interval 57
# No match found for s03, week_3, run_01, Interval 58
# No match found for s03, week_3, run_01, Interval 59
# No match found for s03, week_3, run_01, Interval 60
# No match found for s03, week_3, run_01, Interval 68
# No match found for s03, week_3, run_01, Interval 84
# No match found for s03, week_3, run_01, Interval 117
# No match found for s03, week_3, run_01, Interval 127
# No match found for s03, week_3, run_01, Interval 128
# No match found for s03, week_3, run_01, Interval 129
# No match found for s03, week_3, run_01, Interval 130
# No match found for s03, week_3, run_01, Interval 131
# No match found for s03, week_3, run_01, Interval 132
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# No match found for s03, week_3, run_04, Interval 136
# Mapping session_session_5 to run_05
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# Mapping session_session_4 to run_04
# No match found for s03, week_4, run_04, Interval 45
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# No match found for s04, week_1, run_01, Interval 43
# Mapping session_session_2 to run_02
# No match found for s04, week_1, run_02, Interval 43
# Mapping session_session_3 to run_03
# No match found for s04, week_1, run_03, Interval 43
# Mapping session_session_4 to run_04
# No match found for s04, week_1, run_04, Interval 7
# No match found for s04, week_1, run_04, Interval 9
# No match found for s04, week_1, run_04, Interval 10
# No match found for s04, week_1, run_04, Interval 11
# No match found for s04, week_1, run_04, Interval 12
# No match found for s04, week_1, run_04, Interval 13
# No match found for s04, week_1, run_04, Interval 14
# No match found for s04, week_1, run_04, Interval 15
# No match found for s04, week_1, run_04, Interval 16
# No match found for s04, week_1, run_04, Interval 17
# No match found for s04, week_1, run_04, Interval 18
# No match found for s04, week_1, run_04, Interval 19
# No match found for s04, week_1, run_04, Interval 20
# No match found for s04, week_1, run_04, Interval 21
# No match found for s04, week_1, run_04, Interval 22
# No match found for s04, week_1, run_04, Interval 23
# No match found for s04, week_1, run_04, Interval 24
# No match found for s04, week_1, run_04, Interval 25
# No match found for s04, week_1, run_04, Interval 26
# No match found for s04, week_1, run_04, Interval 27
# No match found for s04, week_1, run_04, Interval 28
# No match found for s04, week_1, run_04, Interval 29
# No match found for s04, week_1, run_04, Interval 30
# No match found for s04, week_1, run_04, Interval 31
# No match found for s04, week_1, run_04, Interval 32
# No match found for s04, week_1, run_04, Interval 33
# No match found for s04, week_1, run_04, Interval 34
# No match found for s04, week_1, run_04, Interval 35
# No match found for s04, week_1, run_04, Interval 36
# No match found for s04, week_1, run_04, Interval 37
# No match found for s04, week_1, run_04, Interval 38
# No match found for s04, week_1, run_04, Interval 39
# No match found for s04, week_1, run_04, Interval 40
# No match found for s04, week_1, run_04, Interval 41
# No match found for s04, week_1, run_04, Interval 42
# No match found for s04, week_1, run_04, Interval 43
# Mapping session_session_5 to run_05
# No match found for s04, week_1, run_05, Interval 43
# Mapping session_session_6 to run_06
# No match found for s04, week_1, run_06, Interval 13
# No match found for s04, week_1, run_06, Interval 16
# No match found for s04, week_1, run_06, Interval 17
# No match found for s04, week_1, run_06, Interval 18
# No match found for s04, week_1, run_06, Interval 19
# No match found for s04, week_1, run_06, Interval 20
# No match found for s04, week_1, run_06, Interval 21
# No match found for s04, week_1, run_06, Interval 22
# No match found for s04, week_1, run_06, Interval 24
# No match found for s04, week_1, run_06, Interval 25
# No match found for s04, week_1, run_06, Interval 26
# No match found for s04, week_1, run_06, Interval 27
# No match found for s04, week_1, run_06, Interval 28
# No match found for s04, week_1, run_06, Interval 29
# No match found for s04, week_1, run_06, Interval 30
# No match found for s04, week_1, run_06, Interval 31
# No match found for s04, week_1, run_06, Interval 32
# No match found for s04, week_1, run_06, Interval 33
# No match found for s04, week_1, run_06, Interval 34
# No match found for s04, week_1, run_06, Interval 35
# No match found for s04, week_1, run_06, Interval 36
# No match found for s04, week_1, run_06, Interval 37
# No match found for s04, week_1, run_06, Interval 38
# No match found for s04, week_1, run_06, Interval 39
# No match found for s04, week_1, run_06, Interval 40
# No match found for s04, week_1, run_06, Interval 41
# No match found for s04, week_1, run_06, Interval 42
# Mapping session_session_7 to run_07
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_1 to run_01
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_1 to run_01
# Mapping session_session_3 to run_03
# No match found for s04, week_4, run_03, Interval 0
# No match found for s04, week_4, run_03, Interval 2
# No match found for s04, week_4, run_03, Interval 3
# No match found for s04, week_4, run_03, Interval 4
# No match found for s04, week_4, run_03, Interval 5
# No match found for s04, week_4, run_03, Interval 6
# No match found for s04, week_4, run_03, Interval 7
# No match found for s04, week_4, run_03, Interval 8
# No match found for s04, week_4, run_03, Interval 9
# No match found for s04, week_4, run_03, Interval 10
# No match found for s04, week_4, run_03, Interval 11
# No match found for s04, week_4, run_03, Interval 12
# No match found for s04, week_4, run_03, Interval 13
# No match found for s04, week_4, run_03, Interval 14
# No match found for s04, week_4, run_03, Interval 15
# No match found for s04, week_4, run_03, Interval 16
# No match found for s04, week_4, run_03, Interval 17
# No match found for s04, week_4, run_03, Interval 18
# No match found for s04, week_4, run_03, Interval 19
# No match found for s04, week_4, run_03, Interval 20
# No match found for s04, week_4, run_03, Interval 21
# No match found for s04, week_4, run_03, Interval 22
# No match found for s04, week_4, run_03, Interval 23
# No match found for s04, week_4, run_03, Interval 24
# No match found for s04, week_4, run_03, Interval 25
# No match found for s04, week_4, run_03, Interval 26
# No match found for s04, week_4, run_03, Interval 27
# No match found for s04, week_4, run_03, Interval 28
# No match found for s04, week_4, run_03, Interval 29
# No match found for s04, week_4, run_03, Interval 30
# No match found for s04, week_4, run_03, Interval 31
# No match found for s04, week_4, run_03, Interval 32
# No match found for s04, week_4, run_03, Interval 33
# No match found for s04, week_4, run_03, Interval 34
# No match found for s04, week_4, run_03, Interval 35
# No match found for s04, week_4, run_03, Interval 36
# No match found for s04, week_4, run_03, Interval 37
# No match found for s04, week_4, run_03, Interval 38
# No match found for s04, week_4, run_03, Interval 41
# No match found for s04, week_4, run_03, Interval 42
# No match found for s04, week_4, run_03, Interval 43
# No match found for s04, week_4, run_03, Interval 44
# Mapping session_session_4 to run_04
# No match found for s04, week_4, run_04, Interval 45
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# No match found for s07, week_1, run_04, Interval 2
# No match found for s07, week_1, run_04, Interval 13
# No match found for s07, week_1, run_04, Interval 14
# No match found for s07, week_1, run_04, Interval 15
# No match found for s07, week_1, run_04, Interval 16
# No match found for s07, week_1, run_04, Interval 17
# No match found for s07, week_1, run_04, Interval 18
# No match found for s07, week_1, run_04, Interval 19
# No match found for s07, week_1, run_04, Interval 20
# No match found for s07, week_1, run_04, Interval 21
# No match found for s07, week_1, run_04, Interval 23
# No match found for s07, week_1, run_04, Interval 27
# No match found for s07, week_1, run_04, Interval 29
# No match found for s07, week_1, run_04, Interval 31
# No match found for s07, week_1, run_04, Interval 32
# No match found for s07, week_1, run_04, Interval 33
# No match found for s07, week_1, run_04, Interval 34
# No match found for s07, week_1, run_04, Interval 35
# No match found for s07, week_1, run_04, Interval 36
# No match found for s07, week_1, run_04, Interval 37
# No match found for s07, week_1, run_04, Interval 39
# No match found for s07, week_1, run_04, Interval 40
# No match found for s07, week_1, run_04, Interval 41
# No match found for s07, week_1, run_04, Interval 42
# No match found for s07, week_1, run_04, Interval 43
# Mapping session_session_5 to run_05
# No match found for s07, week_1, run_05, Interval 43
# Mapping session_session_6 to run_06
# No match found for s07, week_1, run_06, Interval 43
# Mapping session_session_7 to run_07
# No match found for s07, week_1, run_07, Interval 43
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# No match found for s07, week_2, run_02, Interval 97
# Mapping session_session_3 to run_03
# No match found for s07, week_2, run_03, Interval 97
# Mapping session_session_4 to run_04
# No match found for s07, week_2, run_04, Interval 97
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# No match found for s07, week_2, run_06, Interval 97
# Mapping session_session_7 to run_07
# No match found for s07, week_2, run_07, Interval 97
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# No match found for s07, week_3, run_02, Interval 0
# No match found for s07, week_3, run_02, Interval 1
# No match found for s07, week_3, run_02, Interval 2
# No match found for s07, week_3, run_02, Interval 3
# No match found for s07, week_3, run_02, Interval 4
# No match found for s07, week_3, run_02, Interval 5
# No match found for s07, week_3, run_02, Interval 6
# No match found for s07, week_3, run_02, Interval 7
# No match found for s07, week_3, run_02, Interval 8
# No match found for s07, week_3, run_02, Interval 9
# No match found for s07, week_3, run_02, Interval 10
# No match found for s07, week_3, run_02, Interval 11
# No match found for s07, week_3, run_02, Interval 12
# No match found for s07, week_3, run_02, Interval 13
# No match found for s07, week_3, run_02, Interval 14
# No match found for s07, week_3, run_02, Interval 15
# No match found for s07, week_3, run_02, Interval 16
# No match found for s07, week_3, run_02, Interval 17
# No match found for s07, week_3, run_02, Interval 18
# No match found for s07, week_3, run_02, Interval 19
# No match found for s07, week_3, run_02, Interval 21
# No match found for s07, week_3, run_02, Interval 24
# No match found for s07, week_3, run_02, Interval 31
# No match found for s07, week_3, run_02, Interval 32
# No match found for s07, week_3, run_02, Interval 33
# No match found for s07, week_3, run_02, Interval 34
# No match found for s07, week_3, run_02, Interval 35
# No match found for s07, week_3, run_02, Interval 36
# No match found for s07, week_3, run_02, Interval 37
# No match found for s07, week_3, run_02, Interval 38
# No match found for s07, week_3, run_02, Interval 41
# No match found for s07, week_3, run_02, Interval 50
# No match found for s07, week_3, run_02, Interval 51
# No match found for s07, week_3, run_02, Interval 52
# No match found for s07, week_3, run_02, Interval 53
# No match found for s07, week_3, run_02, Interval 54
# No match found for s07, week_3, run_02, Interval 55
# No match found for s07, week_3, run_02, Interval 69
# No match found for s07, week_3, run_02, Interval 70
# No match found for s07, week_3, run_02, Interval 71
# No match found for s07, week_3, run_02, Interval 72
# No match found for s07, week_3, run_02, Interval 73
# No match found for s07, week_3, run_02, Interval 74
# No match found for s07, week_3, run_02, Interval 75
# No match found for s07, week_3, run_02, Interval 76
# No match found for s07, week_3, run_02, Interval 77
# No match found for s07, week_3, run_02, Interval 78
# No match found for s07, week_3, run_02, Interval 80
# No match found for s07, week_3, run_02, Interval 82
# No match found for s07, week_3, run_02, Interval 91
# No match found for s07, week_3, run_02, Interval 95
# No match found for s07, week_3, run_02, Interval 96
# No match found for s07, week_3, run_02, Interval 97
# No match found for s07, week_3, run_02, Interval 98
# No match found for s07, week_3, run_02, Interval 99
# No match found for s07, week_3, run_02, Interval 100
# No match found for s07, week_3, run_02, Interval 101
# No match found for s07, week_3, run_02, Interval 102
# No match found for s07, week_3, run_02, Interval 108
# No match found for s07, week_3, run_02, Interval 109
# No match found for s07, week_3, run_02, Interval 111
# No match found for s07, week_3, run_02, Interval 112
# No match found for s07, week_3, run_02, Interval 115
# No match found for s07, week_3, run_02, Interval 116
# No match found for s07, week_3, run_02, Interval 117
# No match found for s07, week_3, run_02, Interval 118
# No match found for s07, week_3, run_02, Interval 119
# No match found for s07, week_3, run_02, Interval 120
# No match found for s07, week_3, run_02, Interval 121
# No match found for s07, week_3, run_02, Interval 122
# No match found for s07, week_3, run_02, Interval 123
# No match found for s07, week_3, run_02, Interval 124
# No match found for s07, week_3, run_02, Interval 125
# No match found for s07, week_3, run_02, Interval 126
# No match found for s07, week_3, run_02, Interval 127
# No match found for s07, week_3, run_02, Interval 128
# No match found for s07, week_3, run_02, Interval 129
# No match found for s07, week_3, run_02, Interval 130
# No match found for s07, week_3, run_02, Interval 131
# No match found for s07, week_3, run_02, Interval 132
# No match found for s07, week_3, run_02, Interval 133
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# No match found for s07, week_4, run_01, Interval 45
# Mapping session_session_4 to run_04
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# No match found for s08, week_2, run_02, Interval 97
# Mapping session_session_3 to run_03
# No match found for s08, week_2, run_03, Interval 97
# Mapping session_session_4 to run_04
# No match found for s08, week_2, run_04, Interval 97
# Mapping session_session_7 to run_07
# No match found for s08, week_2, run_07, Interval 1
# No match found for s08, week_2, run_07, Interval 2
# No match found for s08, week_2, run_07, Interval 3
# No match found for s08, week_2, run_07, Interval 4
# No match found for s08, week_2, run_07, Interval 5
# No match found for s08, week_2, run_07, Interval 6
# No match found for s08, week_2, run_07, Interval 7
# No match found for s08, week_2, run_07, Interval 8
# No match found for s08, week_2, run_07, Interval 9
# No match found for s08, week_2, run_07, Interval 10
# No match found for s08, week_2, run_07, Interval 11
# No match found for s08, week_2, run_07, Interval 12
# No match found for s08, week_2, run_07, Interval 13
# No match found for s08, week_2, run_07, Interval 14
# No match found for s08, week_2, run_07, Interval 15
# No match found for s08, week_2, run_07, Interval 16
# No match found for s08, week_2, run_07, Interval 17
# No match found for s08, week_2, run_07, Interval 18
# No match found for s08, week_2, run_07, Interval 19
# No match found for s08, week_2, run_07, Interval 20
# No match found for s08, week_2, run_07, Interval 21
# No match found for s08, week_2, run_07, Interval 22
# No match found for s08, week_2, run_07, Interval 23
# No match found for s08, week_2, run_07, Interval 24
# No match found for s08, week_2, run_07, Interval 25
# No match found for s08, week_2, run_07, Interval 26
# No match found for s08, week_2, run_07, Interval 27
# No match found for s08, week_2, run_07, Interval 28
# No match found for s08, week_2, run_07, Interval 29
# No match found for s08, week_2, run_07, Interval 30
# No match found for s08, week_2, run_07, Interval 31
# No match found for s08, week_2, run_07, Interval 32
# No match found for s08, week_2, run_07, Interval 33
# No match found for s08, week_2, run_07, Interval 34
# No match found for s08, week_2, run_07, Interval 35
# No match found for s08, week_2, run_07, Interval 36
# No match found for s08, week_2, run_07, Interval 37
# No match found for s08, week_2, run_07, Interval 38
# ...
# No match found for s14, week_2, run_02, Interval 56
# No match found for s14, week_2, run_02, Interval 57
# No match found for s14, week_2, run_02, Interval 58
# No match found for s14, week_2, run_02, Interval 59
# No match found for s14, week_2, run_02, Interval 60
# No match found for s14, week_2, run_02, Interval 61
# No match found for s14, week_2, run_02, Interval 62
# No match found for s14, week_2, run_02, Interval 63
# No match found for s14, week_2, run_02, Interval 64
# No match found for s14, week_2, run_02, Interval 65
# No match found for s14, week_2, run_02, Interval 66
# No match found for s14, week_2, run_02, Interval 67
# No match found for s14, week_2, run_02, Interval 68
# No match found for s14, week_2, run_02, Interval 69
# No match found for s14, week_2, run_02, Interval 70
# No match found for s14, week_2, run_02, Interval 71
# No match found for s14, week_2, run_02, Interval 72
# No match found for s14, week_2, run_02, Interval 73
# No match found for s14, week_2, run_02, Interval 74
# No match found for s14, week_2, run_02, Interval 75
# No match found for s14, week_2, run_02, Interval 76
# No match found for s14, week_2, run_02, Interval 77
# No match found for s14, week_2, run_02, Interval 78
# No match found for s14, week_2, run_02, Interval 79
# No match found for s14, week_2, run_02, Interval 80
# No match found for s14, week_2, run_02, Interval 81
# No match found for s14, week_2, run_02, Interval 82
# No match found for s14, week_2, run_02, Interval 83
# No match found for s14, week_2, run_02, Interval 84
# No match found for s14, week_2, run_02, Interval 85
# No match found for s14, week_2, run_02, Interval 86
# No match found for s14, week_2, run_02, Interval 87
# No match found for s14, week_2, run_02, Interval 88
# No match found for s14, week_2, run_02, Interval 89
# No match found for s14, week_2, run_02, Interval 90
# No match found for s14, week_2, run_02, Interval 91
# Mapping session_session_3 to run_03
# No match found for s14, week_2, run_03, Interval 97
# Mapping session_session_4 to run_04
# No match found for s14, week_2, run_04, Interval 97
# Mapping session_session_6 to run_06
# No match found for s14, week_2, run_06, Interval 97
# Mapping session_session_7 to run_07
# No match found for s14, week_2, run_07, Interval 97
# Mapping session_session_8 to session_session_8
# No match found for s14, week_2, session_session_8, Interval 1
# No match found for s14, week_2, session_session_8, Interval 5
# No match found for s14, week_2, session_session_8, Interval 6
# No match found for s14, week_2, session_session_8, Interval 8
# No match found for s14, week_2, session_session_8, Interval 30
# No match found for s14, week_2, session_session_8, Interval 32
# No match found for s14, week_2, session_session_8, Interval 65
# No match found for s14, week_2, session_session_8, Interval 69
# No match found for s14, week_2, session_session_8, Interval 75
# No match found for s14, week_2, session_session_8, Interval 77
# No match found for s14, week_2, session_session_8, Interval 78
# No match found for s14, week_2, session_session_8, Interval 79
# No match found for s14, week_2, session_session_8, Interval 86
# No match found for s14, week_2, session_session_8, Interval 87
# No match found for s14, week_2, session_session_8, Interval 91
# No match found for s14, week_2, session_session_8, Interval 94
# No match found for s14, week_2, session_session_8, Interval 95
# No match found for s14, week_2, session_session_8, Interval 96
# No match found for s14, week_2, session_session_8, Interval 97
# Mapping session_session_1 to run_01
# No match found for s14, week_3, run_01, Interval 4
# No match found for s14, week_3, run_01, Interval 5
# No match found for s14, week_3, run_01, Interval 7
# No match found for s14, week_3, run_01, Interval 8
# No match found for s14, week_3, run_01, Interval 11
# No match found for s14, week_3, run_01, Interval 12
# No match found for s14, week_3, run_01, Interval 15
# No match found for s14, week_3, run_01, Interval 31
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# No match found for s14, week_3, run_04, Interval 136
# Mapping session_session_5 to run_05
# No match found for s14, week_3, run_05, Interval 136
# Mapping session_session_6 to run_06
# Mapping session_session_7 to run_07
# No match found for s14, week_3, run_07, Interval 0
# No match found for s14, week_3, run_07, Interval 5
# No match found for s14, week_3, run_07, Interval 12
# No match found for s14, week_3, run_07, Interval 14
# No match found for s14, week_3, run_07, Interval 16
# No match found for s14, week_3, run_07, Interval 17
# No match found for s14, week_3, run_07, Interval 19
# No match found for s14, week_3, run_07, Interval 20
# No match found for s14, week_3, run_07, Interval 22
# No match found for s14, week_3, run_07, Interval 23
# No match found for s14, week_3, run_07, Interval 24
# No match found for s14, week_3, run_07, Interval 25
# No match found for s14, week_3, run_07, Interval 26
# No match found for s14, week_3, run_07, Interval 27
# No match found for s14, week_3, run_07, Interval 28
# No match found for s14, week_3, run_07, Interval 29
# No match found for s14, week_3, run_07, Interval 30
# No match found for s14, week_3, run_07, Interval 31
# No match found for s14, week_3, run_07, Interval 32
# No match found for s14, week_3, run_07, Interval 33
# No match found for s14, week_3, run_07, Interval 34
# No match found for s14, week_3, run_07, Interval 35
# No match found for s14, week_3, run_07, Interval 36
# No match found for s14, week_3, run_07, Interval 37
# No match found for s14, week_3, run_07, Interval 38
# No match found for s14, week_3, run_07, Interval 39
# No match found for s14, week_3, run_07, Interval 40
# No match found for s14, week_3, run_07, Interval 41
# No match found for s14, week_3, run_07, Interval 42
# No match found for s14, week_3, run_07, Interval 43
# No match found for s14, week_3, run_07, Interval 44
# No match found for s14, week_3, run_07, Interval 45
# No match found for s14, week_3, run_07, Interval 46
# No match found for s14, week_3, run_07, Interval 47
# No match found for s14, week_3, run_07, Interval 48
# No match found for s14, week_3, run_07, Interval 49
# No match found for s14, week_3, run_07, Interval 50
# No match found for s14, week_3, run_07, Interval 51
# No match found for s14, week_3, run_07, Interval 52
# No match found for s14, week_3, run_07, Interval 53
# No match found for s14, week_3, run_07, Interval 54
# No match found for s14, week_3, run_07, Interval 55
# No match found for s14, week_3, run_07, Interval 56
# No match found for s14, week_3, run_07, Interval 57
# No match found for s14, week_3, run_07, Interval 58
# No match found for s14, week_3, run_07, Interval 59
# No match found for s14, week_3, run_07, Interval 60
# No match found for s14, week_3, run_07, Interval 61
# No match found for s14, week_3, run_07, Interval 62
# No match found for s14, week_3, run_07, Interval 63
# No match found for s14, week_3, run_07, Interval 64
# No match found for s14, week_3, run_07, Interval 65
# No match found for s14, week_3, run_07, Interval 66
# No match found for s14, week_3, run_07, Interval 67
# No match found for s14, week_3, run_07, Interval 68
# No match found for s14, week_3, run_07, Interval 69
# No match found for s14, week_3, run_07, Interval 70
# No match found for s14, week_3, run_07, Interval 71
# No match found for s14, week_3, run_07, Interval 72
# No match found for s14, week_3, run_07, Interval 73
# No match found for s14, week_3, run_07, Interval 74
# No match found for s14, week_3, run_07, Interval 75
# No match found for s14, week_3, run_07, Interval 76
# No match found for s14, week_3, run_07, Interval 77
# No match found for s14, week_3, run_07, Interval 78
# No match found for s14, week_3, run_07, Interval 79
# No match found for s14, week_3, run_07, Interval 80
# No match found for s14, week_3, run_07, Interval 81
# No match found for s14, week_3, run_07, Interval 82
# No match found for s14, week_3, run_07, Interval 83
# No match found for s14, week_3, run_07, Interval 84
# No match found for s14, week_3, run_07, Interval 85
# No match found for s14, week_3, run_07, Interval 86
# No match found for s14, week_3, run_07, Interval 87
# No match found for s14, week_3, run_07, Interval 90
# No match found for s14, week_3, run_07, Interval 91
# No match found for s14, week_3, run_07, Interval 92
# No match found for s14, week_3, run_07, Interval 93
# No match found for s14, week_3, run_07, Interval 94
# No match found for s14, week_3, run_07, Interval 95
# No match found for s14, week_3, run_07, Interval 96
# No match found for s14, week_3, run_07, Interval 97
# No match found for s14, week_3, run_07, Interval 98
# No match found for s14, week_3, run_07, Interval 99
# No match found for s14, week_3, run_07, Interval 100
# No match found for s14, week_3, run_07, Interval 101
# No match found for s14, week_3, run_07, Interval 102
# No match found for s14, week_3, run_07, Interval 103
# No match found for s14, week_3, run_07, Interval 104
# No match found for s14, week_3, run_07, Interval 106
# No match found for s14, week_3, run_07, Interval 107
# No match found for s14, week_3, run_07, Interval 108
# No match found for s14, week_3, run_07, Interval 109
# No match found for s14, week_3, run_07, Interval 110
# No match found for s14, week_3, run_07, Interval 111
# No match found for s14, week_3, run_07, Interval 113
# No match found for s14, week_3, run_07, Interval 114
# No match found for s14, week_3, run_07, Interval 115
# No match found for s14, week_3, run_07, Interval 116
# No match found for s14, week_3, run_07, Interval 117
# No match found for s14, week_3, run_07, Interval 118
# No match found for s14, week_3, run_07, Interval 119
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# No match found for s17, week_1, run_02, Interval 43
# Mapping session_session_3 to run_03
# Mapping session_session_6 to run_06
# No match found for s17, week_1, run_06, Interval 43
# Mapping session_session_7 to run_07
# No match found for s17, week_1, run_07, Interval 43
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# No match found for s17, week_2, run_03, Interval 97
# Mapping session_session_5 to run_05
# No match found for s17, week_2, run_05, Interval 97
# Mapping session_session_2 to run_02
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# No match found for s18, week_1, run_01, Interval 43
# Mapping session_session_2 to run_02
# No match found for s18, week_1, run_02, Interval 43
# Mapping session_session_3 to run_03
# No match found for s18, week_1, run_03, Interval 43
# Mapping session_session_4 to run_04
# No match found for s18, week_1, run_04, Interval 43
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_1 to run_01
# No match found for s18, week_2, run_01, Interval 97
# Mapping session_session_2 to run_02
# No match found for s18, week_2, run_02, Interval 97
# Mapping session_session_3 to run_03
# No match found for s18, week_2, run_03, Interval 97
# Mapping session_session_4 to run_04
# No match found for s18, week_2, run_04, Interval 97
# Mapping session_session_5 to run_05
# No match found for s18, week_2, run_05, Interval 97
# Mapping session_session_6 to run_06
# No match found for s18, week_2, run_06, Interval 97
# Mapping session_session_1 to run_01
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_2 to run_02
# No match found for s21, week_1, run_02, Interval 0
# No match found for s21, week_1, run_02, Interval 1
# No match found for s21, week_1, run_02, Interval 2
# No match found for s21, week_1, run_02, Interval 3
# No match found for s21, week_1, run_02, Interval 4
# No match found for s21, week_1, run_02, Interval 5
# No match found for s21, week_1, run_02, Interval 6
# No match found for s21, week_1, run_02, Interval 7
# No match found for s21, week_1, run_02, Interval 8
# No match found for s21, week_1, run_02, Interval 9
# No match found for s21, week_1, run_02, Interval 10
# No match found for s21, week_1, run_02, Interval 11
# No match found for s21, week_1, run_02, Interval 12
# No match found for s21, week_1, run_02, Interval 13
# No match found for s21, week_1, run_02, Interval 14
# No match found for s21, week_1, run_02, Interval 15
# No match found for s21, week_1, run_02, Interval 16
# No match found for s21, week_1, run_02, Interval 17
# No match found for s21, week_1, run_02, Interval 18
# No match found for s21, week_1, run_02, Interval 19
# No match found for s21, week_1, run_02, Interval 20
# No match found for s21, week_1, run_02, Interval 21
# No match found for s21, week_1, run_02, Interval 22
# No match found for s21, week_1, run_02, Interval 23
# No match found for s21, week_1, run_02, Interval 24
# No match found for s21, week_1, run_02, Interval 25
# No match found for s21, week_1, run_02, Interval 26
# No match found for s21, week_1, run_02, Interval 27
# No match found for s21, week_1, run_02, Interval 28
# No match found for s21, week_1, run_02, Interval 29
# No match found for s21, week_1, run_02, Interval 30
# No match found for s21, week_1, run_02, Interval 31
# No match found for s21, week_1, run_02, Interval 32
# No match found for s21, week_1, run_02, Interval 33
# No match found for s21, week_1, run_02, Interval 34
# No match found for s21, week_1, run_02, Interval 35
# No match found for s21, week_1, run_02, Interval 36
# No match found for s21, week_1, run_02, Interval 37
# No match found for s21, week_1, run_02, Interval 38
# No match found for s21, week_1, run_02, Interval 39
# No match found for s21, week_1, run_02, Interval 40
# No match found for s21, week_1, run_02, Interval 41
# No match found for s21, week_1, run_02, Interval 42
# No match found for s21, week_1, run_02, Interval 43
# Mapping session_session_3 to run_03
# No match found for s21, week_1, run_03, Interval 43
# Mapping session_session_4 to run_04
# No match found for s21, week_1, run_04, Interval 43
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# No match found for s21, week_1, run_06, Interval 43
# Mapping session_session_7 to run_07
# Mapping session_session_1 to run_01
# No match found for s21, week_2, run_01, Interval 97
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# No match found for s21, week_2, run_06, Interval 97
# Mapping session_session_7 to run_07
# No match found for s21, week_2, run_07, Interval 15
# No match found for s21, week_2, run_07, Interval 16
# No match found for s21, week_2, run_07, Interval 17
# No match found for s21, week_2, run_07, Interval 18
# No match found for s21, week_2, run_07, Interval 19
# No match found for s21, week_2, run_07, Interval 39
# No match found for s21, week_2, run_07, Interval 40
# No match found for s21, week_2, run_07, Interval 41
# No match found for s21, week_2, run_07, Interval 42
# No match found for s21, week_2, run_07, Interval 43
# No match found for s21, week_2, run_07, Interval 44
# No match found for s21, week_2, run_07, Interval 45
# No match found for s21, week_2, run_07, Interval 92
# No match found for s21, week_2, run_07, Interval 93
# No match found for s21, week_2, run_07, Interval 94
# No match found for s21, week_2, run_07, Interval 95
# No match found for s21, week_2, run_07, Interval 96
# No match found for s21, week_2, run_07, Interval 97
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02
# Mapping session_session_3 to run_03
# No match found for s21, week_3, run_03, Interval 136
# Mapping session_session_4 to run_04
# Mapping session_session_5 to run_05
# Mapping session_session_6 to run_06
# Mapping session_session_1 to run_01
# Mapping session_session_2 to run_02

# %%
main_df.to_csv("C:/Users/hugma/diss/final/main_df.csv",index=False)
